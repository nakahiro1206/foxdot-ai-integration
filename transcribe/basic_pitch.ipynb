# %%
# !pip install basic_pitch

# %%
from basic_pitch.inference import predict_and_save

predict_and_save(input_audio_path_list, output_directory, save_midi, sonify_midi, save_model_outputs, save_notes)

# %%
import tensorflow as tf
from basic_pitch.inference import predict
from basic_pitch import ICASSP_2022_MODEL_PATH

basic_pitch_model = tf.saved_model.load(str(ICASSP_2022_MODEL_PATH))

for x in range():
    model_output, midi_data, note_events = predict(loop_x_input_audio_path, basic_pitch_model)
